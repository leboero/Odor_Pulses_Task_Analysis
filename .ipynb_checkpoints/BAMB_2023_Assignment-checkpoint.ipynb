# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import scipy
import seaborn as sns
from scipy.stats import norm,entropy,linregress
from scipy.optimize import minimize, curve_fit
from scipy.io import savemat
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import sys

# %%
filepath = os.getcwd() + '/behavioral_data/behavioral_data.csv'
df = pd.read_csv(filepath)
stimulus_levels = df['stimulus_evidence'].unique()
df
# Out:
#      stimulus_evidence  response
# 0                 -0.2         0
# 1                 -0.0         1
# 2                 -1.0         0
# 3                  0.1         1
# 4                 -0.1         0
# ..                 ...       ...
# 495               -1.0         0
# 496               -1.0         0
# 497                1.0         1
# 498                0.2         1
# 499                1.0         1
#
# [500 rows x 2 columns]

# %% [raw]
# df1 = df.groupby(["stimulus_evidence"]).mean()
# df.groupby(['stimulus_evidence']).agg({'C':['mean', 'median'], 'D':'max'})
